# %% [markdown]
# # Experiment: Baseline Runner
#
# This notebook runs each baseline script end-to-end, logs outputs, computes local metrics, and writes a submission file per baseline.

# %%
# Setup
import os
import subprocess

BASELINE_SCRIPTS = [
    "src/baselines/random_baseline.py",
    "src/baselines/popularity.py",
    "src/baselines/recency_popularity.py",
    "src/baselines/user_genre.py",
    "src/baselines/coread.py",
]

OUT_DIR = "submissions"
os.makedirs(OUT_DIR, exist_ok=True)

# %% [markdown]
# ## Run all baselines
#
# Each script will:
# - build a submission file
# - compute local metrics if `--do-local-split` is enabled
# - print detailed logs

# %%
def run_script(path, out_name):
    cmd = [
        "python3",
        path,
        "--do-local-split",
        "--out",
        os.path.join(OUT_DIR, out_name),
    ]
    print(">>>", " ".join(cmd))
    subprocess.run(cmd, check=True)

for script in BASELINE_SCRIPTS:
    name = os.path.splitext(os.path.basename(script))[0]
    out_name = f"submission_{name}.csv"
    run_script("../" + script, out_name)
# Out:
# >>> python3 ../src/baselines/random_baseline.py --do-local-split --out submissions/submission_random_baseline.csv
# [2026-02-05 18:37:25] loading data
# Traceback (most recent call last):
#   File "/Users/artyomkonukhov/Projects/Competitions/Хакатон Академии ИИ «По страницам»/notebooks/../src/baselines/random_baseline.py", line 76, in <module>
#     main()
#   File "/Users/artyomkonukhov/Projects/Competitions/Хакатон Академии ИИ «По страницам»/notebooks/../src/baselines/random_baseline.py", line 42, in main
#     ds = load_data(args.data_dir, args.submit_dir)
#   File "/Users/artyomkonukhov/Projects/Competitions/Хакатон Академии ИИ «По страницам»/notebooks/../src/baselines/../baseline_utils.py", line 42, in load_data
#     users = pd.read_csv(os.path.join(data_dir, "users.csv"))
#   File "/Users/artyomkonukhov/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/Users/artyomkonukhov/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/Users/artyomkonukhov/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py", line 1620, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "/Users/artyomkonukhov/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py", line 1880, in _make_engine
#     self.handles = get_handle(
#   File "/Users/artyomkonukhov/Library/Python/3.9/lib/python/site-packages/pandas/io/common.py", line 873, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: 'data/users.csv'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[7], line 15
#      13 name = os.path.splitext(os.path.basename(script))[0]
#      14 out_name = f"submission_{name}.csv"
# ---> 15 run_script("../" + script, out_name)
#
# Cell In[7], line 10, in run_script(path, out_name)
#       2 cmd = [
#       3     "python3",
#       4     path,
#    (...)
#       7     os.path.join(OUT_DIR, out_name),
#       8 ]
#       9 print(">>>", " ".join(cmd))
# ---> 10 subprocess.run(cmd, check=True)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/subprocess.py:528, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     526     retcode = process.poll()
#     527     if check and retcode:
# --> 528         raise CalledProcessError(retcode, process.args,
#     529                                  output=stdout, stderr=stderr)
#     530 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['python3', '../src/baselines/random_baseline.py', '--do-local-split', '--out', 'submissions/submission_random_baseline.csv']' returned non-zero exit status 1.
